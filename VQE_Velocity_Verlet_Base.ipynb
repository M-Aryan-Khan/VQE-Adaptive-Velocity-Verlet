# %% [markdown]
# <a href="https://colab.research.google.com/github/M-Aryan-Khan/VQE-Adaptive-Velocity-Verlet/blob/main/VQE_Velocity_Verlet_Base.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/G0wOz1PV/VQE.git
# Out:
# Cloning into 'VQE'...
# remote: Enumerating objects: 56, done.
# remote: Counting objects: 100% (56/56), done.
# remote: Compressing objects: 100% (53/53), done.
# remote: Total 56 (delta 16), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (56/56), 1.30 MiB | 10.04 MiB/s, done.
# Resolving deltas: 100% (16/16), done.

# %%
# %cd VQE

# !pip install qiskit qiskit-aer qiskit-nature matplotlib pylatexenc
# Out:
# /content/VQE
# Requirement already satisfied: qiskit in /usr/local/lib/python3.12/dist-packages (2.4.1)
# Requirement already satisfied: qiskit-aer in /usr/local/lib/python3.12/dist-packages (0.17.2)
# Requirement already satisfied: qiskit-nature in /usr/local/lib/python3.12/dist-packages (0.7.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (3.10.0)
# Requirement already satisfied: pylatexenc in /usr/local/lib/python3.12/dist-packages (2.10)
# Requirement already satisfied: rustworkx>=0.15.0 in /usr/local/lib/python3.12/dist-packages (from qiskit) (0.17.1)
# Requirement already satisfied: numpy<3,>=1.21 in /usr/local/lib/python3.12/dist-packages (from qiskit) (2.0.2)
# Requirement already satisfied: scipy>=1.5 in /usr/local/lib/python3.12/dist-packages (from qiskit) (1.16.3)
# Requirement already satisfied: dill>=0.3 in /usr/local/lib/python3.12/dist-packages (from qiskit) (0.3.8)
# Requirement already satisfied: stevedore>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from qiskit) (5.8.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.12/dist-packages (from qiskit) (4.15.0)
# Requirement already satisfied: psutil>=5 in /usr/local/lib/python3.12/dist-packages (from qiskit-aer) (5.9.5)
# Requirement already satisfied: python-dateutil>=2.8.0 in /usr/local/lib/python3.12/dist-packages (from qiskit-aer) (2.9.0.post0)
# Requirement already satisfied: qiskit-algorithms>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from qiskit-nature) (0.4.0)
# Requirement already satisfied: setuptools>=40.1.0 in /usr/local/lib/python3.12/dist-packages (from qiskit-nature) (75.2.0)
# Requirement already satisfied: h5py in /usr/local/lib/python3.12/dist-packages (from qiskit-nature) (3.16.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (26.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.0->qiskit-aer) (1.17.0)

# %%
# %cd Velocity\ Verlet
# Out:
# /content/VQE/Velocity Verlet

# %%
# !python main.py
# Out:
#   File "/content/VQE/Velocity Verlet/main.py", line 4
#     !pip install qulacs pyscf openfermion openfermionpyscf --quiet
#     ^
# SyntaxError: invalid syntax

# %%
try:
    import google.colab
    print("Google Colab environment detected. Installing necessary packages...")
    get_ipython().system('pip install qulacs pyscf openfermion openfermionpyscf --quiet')
    get_ipython().system('pip install py-cpuinfo --quiet')
    get_ipython().system('pip install numpy==1.24 --quiet')
except ImportError:
    print("Not in a Google Colab environment.")

import numpy as np
import matplotlib.pyplot as plt
import time
import pandas as pd
from matplotlib.ticker import ScalarFormatter
from scipy.optimize import minimize
import cpuinfo

# PySCF
from openfermion.chem import MolecularData
from openfermionpyscf import run_pyscf
from openfermion.transforms import get_fermion_operator, jordan_wigner

# Qulacs
from qulacs import Observable, QuantumState, QuantumCircuit
from qulacs.observable import create_observable_from_openfermion_text
from qulacs.gate import CZ, RY, RZ, merge

class EvaluationCounter:
    def __init__(self, func):
        self.func = func
        self.count = 0

    def __call__(self, *args, **kwargs):
        self.count += 1
        return self.func(*args, **kwargs)

    def reset(self):
        self.count = 0

def get_cpu_info():
    try:
        info = cpuinfo.get_cpu_info()
        return info['brand_raw']
    except:
        return "Could not determine CPU info."

def setup_molecule_and_hamiltonian(name, distance):
    print(f"Setting up molecule: {name} at distance {distance} Å")
    basis = "sto-3g"
    multiplicity = 1

    if name.lower() == 'h2':
        charge = 0
        geometry = [["H", [0, 0, 0]], ["H", [0, 0, distance]]]
    elif name.lower() == 'lih':
        charge = 0
        geometry = [["Li", [0, 0, 0]], ["H", [0, 0, distance]]]
    else:
        raise ValueError(f"Molecule '{name}' is not supported.")

    molecule = MolecularData(geometry, basis, multiplicity, charge)
    molecule = run_pyscf(molecule, run_scf=1, run_fci=1)

    n_qubit = molecule.n_qubits
    n_electron = molecule.n_electrons

    fermionic_hamiltonian = get_fermion_operator(molecule.get_molecular_hamiltonian())
    jw_hamiltonian = jordan_wigner(fermionic_hamiltonian)
    qulacs_hamiltonian = create_observable_from_openfermion_text(str(jw_hamiltonian))

    print(f"Number of qubits: {n_qubit}")
    print(f"Number of electrons: {n_electron}")
    print(f"FCI (exact) energy: {molecule.fci_energy:.10f} Hartree")

    return molecule, qulacs_hamiltonian, n_qubit, n_electron


def he_ansatz_circuit(n_qubit, depth, theta_list):
    circuit = QuantumCircuit(n_qubit)
    num_params_per_layer = 2 * n_qubit

    for d in range(depth):
        for i in range(n_qubit):
            circuit.add_gate(merge(RY(i, theta_list[d * num_params_per_layer + 2 * i]),
                                  RZ(i, theta_list[d * num_params_per_layer + 2 * i + 1])))

        for i in range(n_qubit//2):
            circuit.add_gate(CZ(2*i, 2*i+1))
        for i in range(n_qubit//2-1):
            circuit.add_gate(CZ(2*i+1, 2*i+2))

    d = depth
    for i in range(n_qubit):
        circuit.add_gate(merge(RY(i, theta_list[d * num_params_per_layer + 2 * i]),
                              RZ(i, theta_list[d * num_params_per_layer + 2 * i + 1])))

    return circuit

def create_cost_and_gradient_functions(n_qubit, depth, qulacs_hamiltonian):
    def cost_func(theta_list):
        state = QuantumState(n_qubit)
        circuit = he_ansatz_circuit(n_qubit, depth, theta_list)
        circuit.update_quantum_state(state)
        return qulacs_hamiltonian.get_expectation_value(state).real

    cost_func_counted = EvaluationCounter(cost_func)

    def compute_gradient(theta_list, eps=1e-4):
        gradient = np.zeros_like(theta_list)
        for i in range(len(theta_list)):
            theta_plus = theta_list.copy()
            theta_plus[i] += eps
            theta_minus = theta_list.copy()
            theta_minus[i] -= eps
            grad_i = (cost_func_counted(theta_plus) - cost_func_counted(theta_minus)) / (2 * eps)
            gradient[i] = grad_i
        return gradient

    return cost_func_counted, compute_gradient


def velocity_verlet_optimizer(cost_func, gradient_func, init_params, vv_params, max_iter=50, tol=1e-10):
    params = init_params.copy()
    velocity = np.zeros_like(params)

    cost_history = []
    eval_count_history = []

    initial_cost = cost_func(params)
    cost_history.append(initial_cost)
    eval_count_history.append(cost_func.count)

    for i in range(max_iter):
        start_eval_count = cost_func.count

        force = -gradient_func(params)
        velocity += 10000 * vv_params['dt'] * force / vv_params['mass']
        params += vv_params['dt'] * velocity
        force_new = -gradient_func(params)
        velocity += 100 * vv_params['dt'] * force_new / vv_params['mass']
        velocity *= vv_params['damping']

        current_cost = cost_func(params)
        cost_history.append(current_cost)
        eval_count_history.append(cost_func.count)

        if i > 0 and abs(cost_history[-1] - cost_history[-2]) < tol:
            print(f"Velocity Verlet converged at iteration {i}")
            break

        if i % 5 == 0 or i == max_iter - 1:
            print(f"VV - Iter {i}, Cost: {current_cost:.8f}, Evals: {cost_func.count}")

    while len(cost_history) < max_iter + 1:
        cost_history.append(cost_history[-1])
        eval_count_history.append(eval_count_history[-1])

    return params, cost_history, eval_count_history

def run_scipy_optimizer(method, init_params, cost_func, gradient_func, max_iter):
    cost_history = [cost_func(init_params)]
    eval_counts = [cost_func.count]
    param_history = [init_params.copy()]
    def callback(xk):
        if len(cost_history) > max_iter:
            return

        cost = cost_func(xk)
        cost_history.append(cost)
        eval_counts.append(cost_func.count)
        param_history.append(xk.copy())

        current_iter = len(cost_history) - 1
        if current_iter > 0 and (current_iter % 5 == 0 or current_iter == max_iter):
             print(f"{method} - Iter {current_iter}, Cost: {cost:.8f}, Evals: {cost_func.count}")

    start_time = time.time()

    if method == "COBYLA":
        options = {'maxfun': 5000}
        result = minimize(cost_func, init_params, method=method,
                          options=options, callback=callback, tol=1e-6)
    else:
        options = {'maxiter': max_iter}
        result = minimize(cost_func, init_params, method=method,
                          jac=gradient_func, options=options, callback=callback)

    end_time = time.time()
    optimization_time = end_time - start_time

    final_cost_history = cost_history[:max_iter + 1]
    final_eval_counts = eval_counts[:max_iter + 1]
    final_param_history = param_history[:max_iter + 1]

    while len(final_cost_history) < max_iter + 1:
        final_cost_history.append(final_cost_history[-1])
        final_eval_counts.append(final_eval_counts[-1])
        final_param_history.append(final_param_history[-1])

    final_params = final_param_history[-1]

    return final_params, final_cost_history, final_eval_counts, optimization_time

def compare_optimizers(cost_func, gradient_func, n_qubit, depth, fci_energy, vv_params, max_iter=40):
    np.random.seed(18)
    num_params = 2 * n_qubit * (depth + 1)
    init_params = np.random.random(num_params) * 1e-1

    results = {}

    print("\n=== Running Velocity Verlet ===")
    cost_func.reset()
    start_time = time.time()
    vv_params_opt, vv_history, vv_evals = velocity_verlet_optimizer(
        cost_func, gradient_func, init_params, vv_params, max_iter=max_iter
    )
    vv_time = time.time() - start_time
    results["Velocity Verlet"] = {
        "params": vv_params_opt, "history": vv_history, "evals": vv_evals, "time": vv_time
    }

    methods = ["L-BFGS-B", "SLSQP", "COBYLA"]
    for method in methods:
        print(f"\n=== Running {method} ===")
        cost_func.reset()
        opt_params, opt_history, opt_evals, opt_time = run_scipy_optimizer(
            method, init_params, cost_func, gradient_func, max_iter
        )
        results[method] = {
            "params": opt_params, "history": opt_history, "evals": opt_evals, "time": opt_time
        }

    for method, res in results.items():
        final_energy = res['history'][-1]
        res["final_energy"] = final_energy
        res["error"] = abs(final_energy - fci_energy)

    return results

def visualize_results(results, fci_energy, molecule_name, cpu_info):
    import matplotlib.pyplot as plt
    import matplotlib as mpl

    plt.style.use('seaborn-v0_8-whitegrid')

    colors = {"Velocity Verlet": "#636EFA", "L-BFGS-B": "#00CC96", "SLSQP": "#EF553B", "COBYLA": "#FFB000"}
    chemical_accuracy = 1.6e-3

    plt.figure(figsize=(10, 7))
    for method, res in results.items():
        plt.plot(res["history"], label=method, color=colors[method], linewidth=2.5)
    plt.axhline(y=fci_energy, color='black', linestyle='--', label=f'FCI Energy ({fci_energy:.6f})')
    plt.xlabel("Iteration")
    plt.ylabel("Energy (Hartree)")
    plt.title(f"VQE Convergence ({molecule_name})")
    plt.legend()
    plt.tight_layout()
    plt.show()

    data = []
    for method, res in results.items():
        evals_to_chem_acc = "N/A"
        errors = [abs(e - fci_energy) for e in res["history"]]
        for i, error in enumerate(errors):
            if error < chemical_accuracy:
                evals_to_chem_acc = res["evals"][i]
                break

        data.append({
            "Optimizer": method,
            "Final Energy": f"{res['final_energy']:.10f}",
            "Final Error": f"{res['error']:.4e}",
            "Total Evals": res["evals"][-1],
            "Time (s)": f"{res['time']:.2f}",
            "Evals to Chem. Acc.": evals_to_chem_acc
        })
    df = pd.DataFrame(data)

    print("\n" + "="*50)
    print(f"Performance Summary for {molecule_name}")
    print("="*50)
    print(f"FCI Energy: {fci_energy:.10f} Hartree")
    print(df.to_string(index=False))
    print("="*50 + "\n")

    return df

# --- THE FIXED FUNCTION ---
def run_simulation_for_molecule(molecule_config, cpu_info):
    molecule, hamiltonian, n_qubit, n_electron = setup_molecule_and_hamiltonian(
        molecule_config['name'], molecule_config['distance']
    )

    depth = molecule_config.get('depth', n_qubit)
    cost_func, gradient_func = create_cost_and_gradient_functions(n_qubit, depth, hamiltonian)

    results = compare_optimizers(
        cost_func, gradient_func, n_qubit, depth,
        molecule.fci_energy, molecule_config['vv_params'], max_iter=molecule_config['max_iter']
    )

    performance_df = visualize_results(results, molecule.fci_energy, molecule_config['name'], cpu_info)
    return performance_df

if __name__ == "__main__":
    cpu_info = get_cpu_info()
    print(f"--- VQE Optimizer Benchmark ---")
    print(f"Running on: {cpu_info}\n")

    molecules_to_run = [
        {
            "name": "H2",
            "distance": 0.977,
            "max_iter": 40,
            "depth": 4,
            "vv_params": {'dt': 0.01, 'mass': 0.8, 'damping': 0.68}
        },
        {
            "name": "LiH",
            "distance": 1.596,
            "max_iter": 40,
            "depth": 4,
            "vv_params": {'dt': 0.01, 'mass': 1.9, 'damping': 0.68}
        }
    ]

    all_results = {}
    for config in molecules_to_run:
        df = run_simulation_for_molecule(config, cpu_info)
        all_results[config['name']] = df

    print("\n--- All simulations completed. ---")
# Out:
# Google Colab environment detected. Installing necessary packages...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 17.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.0/52.0 MB 18.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.7/44.7 MB 16.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 82.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 42.9 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   error: subprocess-exited-with-error
#
#   × Getting requirements to build wheel did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Getting requirements to build wheel ... error
# error: subprocess-exited-with-error
#
# × Getting requirements to build wheel did not run successfully.
# │ exit code: 1
# ╰─> See above for output.
#
# note: This error originates from a subprocess, and is likely not a problem with pip.
# --- VQE Optimizer Benchmark ---
# Running on: Intel(R) Xeon(R) CPU @ 2.20GHz
#
# Setting up molecule: H2 at distance 0.977 Å
# Number of qubits: 4
# Number of electrons: 2
# FCI (exact) energy: -1.1059333523 Hartree
#
# === Running Velocity Verlet ===
# VV - Iter 0, Cost: -0.06769015, Evals: 162
# VV - Iter 5, Cost: -0.62256820, Evals: 967
# VV - Iter 10, Cost: -0.89073718, Evals: 1772
# VV - Iter 15, Cost: -1.08140901, Evals: 2577
# VV - Iter 20, Cost: -1.10347430, Evals: 3382
# VV - Iter 25, Cost: -1.10569064, Evals: 4187
# VV - Iter 30, Cost: -1.10589119, Evals: 4992
# VV - Iter 35, Cost: -1.10592410, Evals: 5797
# VV - Iter 39, Cost: -1.10592861, Evals: 6441
#
# === Running L-BFGS-B ===
# L-BFGS-B - Iter 5, Cost: -0.72532922, Evals: 654
# L-BFGS-B - Iter 10, Cost: -0.73374260, Evals: 1145
# L-BFGS-B - Iter 15, Cost: -0.76110948, Evals: 2041
# L-BFGS-B - Iter 20, Cost: -1.04394331, Evals: 2532
# L-BFGS-B - Iter 25, Cost: -1.08945903, Evals: 2942
# L-BFGS-B - Iter 30, Cost: -1.09950646, Evals: 3352
# L-BFGS-B - Iter 35, Cost: -1.10264697, Evals: 3762
# L-BFGS-B - Iter 40, Cost: -1.10462260, Evals: 4253
#
# === Running SLSQP ===
# SLSQP - Iter 5, Cost: -0.71141962, Evals: 414
# SLSQP - Iter 10, Cost: -0.72900458, Evals: 824
# SLSQP - Iter 15, Cost: -0.73362312, Evals: 1234
# SLSQP - Iter 20, Cost: -0.73892371, Evals: 1648
# SLSQP - Iter 25, Cost: -0.90114866, Evals: 2062
# SLSQP - Iter 30, Cost: -1.08447831, Evals: 2474
# SLSQP - Iter 35, Cost: -1.09606058, Evals: 2884
# SLSQP - Iter 40, Cost: -1.10133406, Evals: 3294
#
# === Running COBYLA ===
# /tmp/ipykernel_5058/1006765465.py:181: OptimizeWarning: Unknown solver options: maxfun
#   result = minimize(cost_func, init_params, method=method,
# COBYLA - Iter 5, Cost: -0.67512733, Evals: 56
# COBYLA - Iter 10, Cost: -0.72547296, Evals: 70
# COBYLA - Iter 15, Cost: -0.85788289, Evals: 83
# COBYLA - Iter 20, Cost: -0.87183022, Evals: 98
# COBYLA - Iter 25, Cost: -0.96206759, Evals: 112
# COBYLA - Iter 30, Cost: -0.96206759, Evals: 127
# COBYLA - Iter 35, Cost: -0.96206759, Evals: 142
# COBYLA - Iter 40, Cost: -0.96206759, Evals: 156
# ==================================================
# Performance Summary for H2
# ==================================================
# FCI Energy: -1.1059333523 Hartree
#       Optimizer  Final Energy Final Error  Total Evals Time (s) Evals to Chem. Acc.
# Velocity Verlet -1.1059286124  4.7399e-06         6441     1.52                3543
#        L-BFGS-B -1.1046226032  1.3107e-03         4253     2.34                4253
#           SLSQP -1.1013340631  4.5993e-03         3294     4.43                 N/A
#          COBYLA -0.9620675939  1.4387e-01          156     5.86                 N/A
# ==================================================
#
# Setting up molecule: LiH at distance 1.596 Å
# Number of qubits: 12
# Number of electrons: 4
# FCI (exact) energy: -7.8823869936 Hartree
#
# === Running Velocity Verlet ===
# VV - Iter 0, Cost: -4.00410525, Evals: 482
# VV - Iter 5, Cost: -6.16094260, Evals: 2887
# VV - Iter 10, Cost: -7.58632800, Evals: 5292
# VV - Iter 15, Cost: -7.69412713, Evals: 7697
# VV - Iter 20, Cost: -7.82769184, Evals: 10102
# VV - Iter 25, Cost: -7.85553496, Evals: 12507
# VV - Iter 30, Cost: -7.86182870, Evals: 14912
# VV - Iter 35, Cost: -7.86200501, Evals: 17317
# VV - Iter 39, Cost: -7.86205006, Evals: 19241
#
# === Running L-BFGS-B ===
# L-BFGS-B - Iter 5, Cost: -7.29176646, Evals: 1934
# L-BFGS-B - Iter 10, Cost: -7.67825541, Evals: 3144
# L-BFGS-B - Iter 15, Cost: -7.71417204, Evals: 4354
# L-BFGS-B - Iter 20, Cost: -7.72480869, Evals: 5805
# L-BFGS-B - Iter 25, Cost: -7.73134714, Evals: 7015
# L-BFGS-B - Iter 30, Cost: -7.77467703, Evals: 8225
# L-BFGS-B - Iter 35, Cost: -7.84076264, Evals: 9917
# L-BFGS-B - Iter 40, Cost: -7.86121738, Evals: 11127
#
# === Running SLSQP ===
# SLSQP - Iter 5, Cost: -6.18619506, Evals: 1212
# SLSQP - Iter 10, Cost: -7.69933000, Evals: 2423
# SLSQP - Iter 15, Cost: -7.72072828, Evals: 3633
# SLSQP - Iter 20, Cost: -7.72874814, Evals: 4843
# SLSQP - Iter 25, Cost: -7.80971679, Evals: 6056
# SLSQP - Iter 30, Cost: -7.86071506, Evals: 7267
# SLSQP - Iter 35, Cost: -7.86171140, Evals: 8477
# SLSQP - Iter 40, Cost: -7.86190734, Evals: 9687
#
# === Running COBYLA ===
# /tmp/ipykernel_5058/1006765465.py:181: OptimizeWarning: Unknown solver options: maxfun
#   result = minimize(cost_func, init_params, method=method,
# COBYLA - Iter 5, Cost: -6.90363580, Evals: 135
# COBYLA - Iter 10, Cost: -7.07262223, Evals: 148
# COBYLA - Iter 15, Cost: -7.16625328, Evals: 162
# COBYLA - Iter 20, Cost: -7.16745734, Evals: 177
# COBYLA - Iter 25, Cost: -7.16745734, Evals: 192
# COBYLA - Iter 30, Cost: -7.17267422, Evals: 206
# COBYLA - Iter 35, Cost: -7.17267422, Evals: 221
# COBYLA - Iter 40, Cost: -7.17590869, Evals: 236
# ==================================================
# Performance Summary for LiH
# ==================================================
# FCI Energy: -7.8823869936 Hartree
#       Optimizer  Final Energy Final Error  Total Evals Time (s) Evals to Chem. Acc.
# Velocity Verlet -7.8620500646  2.0337e-02        19241   622.78                 N/A
#        L-BFGS-B -7.8612173835  2.1170e-02        11127   348.63                 N/A
#           SLSQP -7.8619073396  2.0480e-02         9687   312.06                 N/A
#          COBYLA -7.1759086855  7.0648e-01          236    70.02                 N/A
# ==================================================
#
#
# --- All simulations completed. ---

# %%
def adaptive_velocity_verlet_optimizer(cost_func, gradient_func, init_params, vv_params, max_iter=50, tol=1e-10):
    params = init_params.copy()
    velocity = np.zeros_like(params)

    cost_history = []
    eval_count_history = []

    dt_history = []
    velocity_magnitude_history = []

    initial_cost = cost_func(params)
    cost_history.append(initial_cost)
    eval_count_history.append(cost_func.count)

    dt = vv_params['dt']

    decay_factor = 0.1
    dt_shrink_rate = 0.5
    dt_growth_rate = 1.05
    max_dt = vv_params['dt'] * 1.5

    for i in range(max_iter):
        force = -gradient_func(params)
        prov_velocity = velocity + (10000 * dt * force / vv_params['mass'])
        new_params = params + dt * prov_velocity
        new_cost = cost_func(new_params)

        hit_brakes = False

        if new_cost > cost_history[-1]:
            velocity = prov_velocity * decay_factor
            dt *= dt_shrink_rate
            current_cost = cost_history[-1]
            hit_brakes = True
        else:
            params = new_params
            force_new = -gradient_func(params)
            velocity = prov_velocity + (100 * dt * force_new / vv_params['mass'])
            velocity *= vv_params['damping']

            dt = min(dt * dt_growth_rate, max_dt)
            current_cost = new_cost

        cost_history.append(current_cost)
        eval_count_history.append(cost_func.count)
        dt_history.append(dt)
        velocity_magnitude_history.append(np.linalg.norm(velocity))

        if not hit_brakes and i > 0 and abs(cost_history[-1] - cost_history[-2]) < tol:
            print(f"Adaptive VV converged at iteration {i}")
            break

    while len(cost_history) < max_iter + 1:
        cost_history.append(cost_history[-1])
        eval_count_history.append(eval_count_history[-1])
        dt_history.append(dt_history[-1] if dt_history else dt)

    extra_data = {
        "dt_history": dt_history,
        "velocity_magnitude": velocity_magnitude_history
    }

    return params, cost_history, eval_count_history, extra_data


def compare_optimizers(cost_func, gradient_func, n_qubit, depth, fci_energy, vv_params, max_iter=40):
    np.random.seed(18)
    num_params = 2 * n_qubit * (depth + 1)
    init_params = np.random.random(num_params) * 1e-1

    results = {}

    print("\n=== Running Velocity Verlet ===")
    cost_func.reset()
    start_time = time.time()
    vv_params_opt, vv_history, vv_evals = velocity_verlet_optimizer(
        cost_func, gradient_func, init_params, vv_params, max_iter=max_iter
    )
    vv_time = time.time() - start_time
    results["Velocity Verlet"] = {
        "params": vv_params_opt, "history": vv_history, "evals": vv_evals, "time": vv_time
    }

    print("\n=== Running ADAPTIVE Velocity Verlet (Proposed) ===")
    cost_func.reset()
    start_time = time.time()

    avv_params_opt, avv_history, avv_evals, avv_extra = adaptive_velocity_verlet_optimizer(
        cost_func, gradient_func, init_params, vv_params, max_iter=max_iter
    )
    avv_time = time.time() - start_time
    results["Adaptive VV"] = {
        "params": avv_params_opt, "history": avv_history, "evals": avv_evals, "time": avv_time, "extra": avv_extra
    }

    methods = ["L-BFGS-B", "SLSQP", "COBYLA"]
    for method in methods:
        print(f"\n=== Running {method} ===")
        cost_func.reset()
        opt_params, opt_history, opt_evals, opt_time = run_scipy_optimizer(
            method, init_params, cost_func, gradient_func, max_iter
        )
        results[method] = {
            "params": opt_params, "history": opt_history, "evals": opt_evals, "time": opt_time
        }

    for method, res in results.items():
        final_energy = res['history'][-1]
        res["final_energy"] = final_energy
        res["error"] = abs(final_energy - fci_energy)

    return results

def visualize_results(results, fci_energy, molecule_name, cpu_info):
    import matplotlib.pyplot as plt
    import matplotlib as mpl
    import pandas as pd

    plt.style.use('seaborn-v0_8-whitegrid')

    colors = {
        "Velocity Verlet": "#636EFA",
        "Adaptive VV": "#AB63FA",
        "L-BFGS-B": "#00CC96",
        "SLSQP": "#EF553B",
        "COBYLA": "#FFB000"
    }
    chemical_accuracy = 1.6e-3

    plt.figure(figsize=(10, 7))
    for method, res in results.items():
        color = colors.get(method, "#888888")
        plt.plot(res["history"], label=method, color=color, linewidth=2.5)

    plt.axhline(y=fci_energy, color='black', linestyle='--', label=f'FCI Energy ({fci_energy:.6f})')
    plt.xlabel("Iteration")
    plt.ylabel("Energy (Hartree)")
    plt.title(f"VQE Convergence ({molecule_name})")
    plt.legend()
    plt.tight_layout()
    plt.show()

    if "Adaptive VV" in results and "extra" in results["Adaptive VV"]:
        extra = results["Adaptive VV"]["extra"]
        dt_hist = extra["dt_history"]

        plt.figure(figsize=(10, 4))
        plt.plot(dt_hist, color="#AB63FA", linewidth=2.5, marker='o')
        plt.axhline(y=0.01, color='gray', linestyle=':', label='Base Paper dt (0.01)')
        plt.title(f"Proof of Proposed Methodology: Dynamic Time-Step Adaptation ({molecule_name})")
        plt.xlabel("Iteration")
        plt.ylabel("Time-Step Size (dt)")
        plt.legend()
        plt.tight_layout()
        plt.show()

    data = []
    for method, res in results.items():
        evals_to_chem_acc = "N/A"
        errors = [abs(e - fci_energy) for e in res["history"]]
        for i, error in enumerate(errors):
            if error < chemical_accuracy:
                evals_to_chem_acc = res["evals"][i]
                break

        data.append({
            "Optimizer": method,
            "Final Energy": f"{res['final_energy']:.10f}",
            "Final Error": f"{res['error']:.4e}",
            "Total Evals": res["evals"][-1],
            "Time (s)": f"{res['time']:.2f}",
            "Evals to Chem. Acc.": evals_to_chem_acc
        })
    df = pd.DataFrame(data)

    print("\n" + "="*50)
    print(f"Performance Summary for {molecule_name}")
    print("="*50)
    print(f"FCI Energy: {fci_energy:.10f} Hartree")
    print(df.to_string(index=False))
    print("="*50 + "\n")

    return df

# %%
all_results = {}
for config in molecules_to_run:
    df = run_simulation_for_molecule(config, cpu_info)
    all_results[config['name']] = df
# Out:
# Setting up molecule: H2 at distance 0.977 Å
# Number of qubits: 4
# Number of electrons: 2
# FCI (exact) energy: -1.1059333523 Hartree
#
# === Running Velocity Verlet ===
# VV - Iter 0, Cost: -0.06769015, Evals: 162
# VV - Iter 5, Cost: -0.62256820, Evals: 967
# VV - Iter 10, Cost: -0.89073718, Evals: 1772
# VV - Iter 15, Cost: -1.08140901, Evals: 2577
# VV - Iter 20, Cost: -1.10347430, Evals: 3382
# VV - Iter 25, Cost: -1.10569064, Evals: 4187
# VV - Iter 30, Cost: -1.10589119, Evals: 4992
# VV - Iter 35, Cost: -1.10592410, Evals: 5797
# VV - Iter 39, Cost: -1.10592861, Evals: 6441
#
# === Running ADAPTIVE Velocity Verlet (Proposed) ===
#
# === Running L-BFGS-B ===
# L-BFGS-B - Iter 5, Cost: -0.72532922, Evals: 654
# L-BFGS-B - Iter 10, Cost: -0.73374260, Evals: 1145
# L-BFGS-B - Iter 15, Cost: -0.76110948, Evals: 2041
# L-BFGS-B - Iter 20, Cost: -1.04394331, Evals: 2532
# L-BFGS-B - Iter 25, Cost: -1.08945903, Evals: 2942
# L-BFGS-B - Iter 30, Cost: -1.09950646, Evals: 3352
# L-BFGS-B - Iter 35, Cost: -1.10264697, Evals: 3762
# L-BFGS-B - Iter 40, Cost: -1.10462260, Evals: 4253
#
# === Running SLSQP ===
# SLSQP - Iter 5, Cost: -0.71141962, Evals: 414
# SLSQP - Iter 10, Cost: -0.72900458, Evals: 824
# SLSQP - Iter 15, Cost: -0.73362312, Evals: 1234
# SLSQP - Iter 20, Cost: -0.73892371, Evals: 1648
# SLSQP - Iter 25, Cost: -0.90114866, Evals: 2062
# SLSQP - Iter 30, Cost: -1.08447831, Evals: 2474
# SLSQP - Iter 35, Cost: -1.09606058, Evals: 2884
# SLSQP - Iter 40, Cost: -1.10133406, Evals: 3294
#
# === Running COBYLA ===
# COBYLA - Iter 5, Cost: -0.67512733, Evals: 56
# /tmp/ipykernel_5058/1006765465.py:181: OptimizeWarning: Unknown solver options: maxfun
#   result = minimize(cost_func, init_params, method=method,
# COBYLA - Iter 10, Cost: -0.72547296, Evals: 70
# COBYLA - Iter 15, Cost: -0.85788289, Evals: 83
# COBYLA - Iter 20, Cost: -0.87183022, Evals: 98
# COBYLA - Iter 25, Cost: -0.96206759, Evals: 112
# COBYLA - Iter 30, Cost: -0.96206759, Evals: 127
# COBYLA - Iter 35, Cost: -0.96206759, Evals: 142
# COBYLA - Iter 40, Cost: -0.96206759, Evals: 156
# ==================================================
# Performance Summary for H2
# ==================================================
# FCI Energy: -1.1059333523 Hartree
#       Optimizer  Final Energy Final Error  Total Evals Time (s) Evals to Chem. Acc.
# Velocity Verlet -1.1059286124  4.7399e-06         6441     3.87                3543
#     Adaptive VV -1.0722272745  3.3706e-02         6121     5.32                 N/A
#        L-BFGS-B -1.1046226032  1.3107e-03         4253     9.02                4253
#           SLSQP -1.1013340631  4.5993e-03         3294     2.39                 N/A
#          COBYLA -0.9620675939  1.4387e-01          156     4.86                 N/A
# ==================================================
#
# Setting up molecule: LiH at distance 1.596 Å
# Number of qubits: 12
# Number of electrons: 4
# FCI (exact) energy: -7.8823869936 Hartree
#
# === Running Velocity Verlet ===
# VV - Iter 0, Cost: -4.00410525, Evals: 482
# VV - Iter 5, Cost: -6.16094260, Evals: 2887
# VV - Iter 10, Cost: -7.58632800, Evals: 5292
# VV - Iter 15, Cost: -7.69412713, Evals: 7697
# VV - Iter 20, Cost: -7.82769184, Evals: 10102
# VV - Iter 25, Cost: -7.85553496, Evals: 12507
# VV - Iter 30, Cost: -7.86182870, Evals: 14912
# VV - Iter 35, Cost: -7.86200501, Evals: 17317
# VV - Iter 39, Cost: -7.86205006, Evals: 19241
#
# === Running ADAPTIVE Velocity Verlet (Proposed) ===
#
# === Running L-BFGS-B ===
# L-BFGS-B - Iter 5, Cost: -7.29176646, Evals: 1934
# L-BFGS-B - Iter 10, Cost: -7.67825541, Evals: 3144
# L-BFGS-B - Iter 15, Cost: -7.71417204, Evals: 4354
# L-BFGS-B - Iter 20, Cost: -7.72480869, Evals: 5805
# L-BFGS-B - Iter 25, Cost: -7.73134714, Evals: 7015
# L-BFGS-B - Iter 30, Cost: -7.77467703, Evals: 8225
# L-BFGS-B - Iter 35, Cost: -7.84076294, Evals: 9917
# L-BFGS-B - Iter 40, Cost: -7.86121740, Evals: 11127
#
# === Running SLSQP ===
# SLSQP - Iter 5, Cost: -6.18619507, Evals: 1212
# SLSQP - Iter 10, Cost: -7.69933000, Evals: 2423
# SLSQP - Iter 15, Cost: -7.72072828, Evals: 3633
# SLSQP - Iter 20, Cost: -7.72874814, Evals: 4843
# SLSQP - Iter 25, Cost: -7.80971682, Evals: 6056
# SLSQP - Iter 30, Cost: -7.86071506, Evals: 7267
# SLSQP - Iter 35, Cost: -7.86171140, Evals: 8477
# SLSQP - Iter 40, Cost: -7.86190734, Evals: 9687
#
# === Running COBYLA ===
# /tmp/ipykernel_5058/1006765465.py:181: OptimizeWarning: Unknown solver options: maxfun
#   result = minimize(cost_func, init_params, method=method,
# COBYLA - Iter 5, Cost: -6.90363580, Evals: 135
# COBYLA - Iter 10, Cost: -7.07262223, Evals: 148
# COBYLA - Iter 15, Cost: -7.16625328, Evals: 162
# COBYLA - Iter 20, Cost: -7.16745734, Evals: 177
# COBYLA - Iter 25, Cost: -7.16745734, Evals: 192
# COBYLA - Iter 30, Cost: -7.17267422, Evals: 206
# COBYLA - Iter 35, Cost: -7.17267422, Evals: 221
# COBYLA - Iter 40, Cost: -7.17590869, Evals: 236
# ==================================================
# Performance Summary for LiH
# ==================================================
# FCI Energy: -7.8823869936 Hartree
#       Optimizer  Final Energy Final Error  Total Evals Time (s) Evals to Chem. Acc.
# Velocity Verlet -7.8620500646  2.0337e-02        19241   609.70                 N/A
#     Adaptive VV -7.7346080332  1.4778e-01        18281   564.30                 N/A
#        L-BFGS-B -7.8612173988  2.1170e-02        11127   348.71                 N/A
#           SLSQP -7.8619073394  2.0480e-02         9687   311.62                 N/A
#          COBYLA -7.1759086855  7.0648e-01          236    70.87                 N/A
# ==================================================
